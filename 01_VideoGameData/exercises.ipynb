# %% [markdown]
# # Exercises

# %%
import pandas as pd

series = pd.Series([5, 10, 15, 20, 25], index=['a', 'b', 'c', 'd', 'e'])
series
# Out:
# a     5
# b    10
# c    15
# d    20
# e    25
# dtype: int64
